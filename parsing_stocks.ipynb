# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('акциии.csv') 
df.head()
# Out:
#          Дата    Цена   Откр.   Макс.    Мин.    Объём  Изм. %
# 0  26.12.2021  416,95  422,00  423,85  416,65  878,25K  -1,28%
# 1  19.12.2021  422,35  404,25  424,25  400,00    1,09M   2,25%
# 2  12.12.2021  413,05  422,05  424,85  409,40    1,88M  -1,90%
# 3  05.12.2021  421,05  402,95  433,65  402,20    1,94M   5,03%
# 4  28.11.2021  400,90  405,90  408,85  392,75    2,78M  -0,35%

# %%
df = df.drop(columns=['Дата'])

# %%
df = df.drop(columns=['Откр.'])

# %%
df = df.drop(columns=['Макс.'])

# %%
df = df.drop(columns=['Мин.'])

# %%
df = df.drop(columns=['Объём'])

# %%
df = df.drop(columns=['Изм. %'])

# %%
df
# Out:
#        Цена
# 0    416,95
# 1    422,35
# 2    413,05
# 3    421,05
# 4    400,90
# ..      ...
# 464  108,60
# 465  111,90
# 466  111,10
# 467  108,30
# 468  103,75
#
# [469 rows x 1 columns]

# %%
df1 = pd.date_range(start='31/12/2012', end = '31/12/2021', freq='W')
df1 = pd.DataFrame(df1)
df1
# Out:
# <ipython-input-74-b3e6ad409849>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1 = pd.date_range(start='31/12/2012', end = '31/12/2021', freq='W')
#              0
# 0   2013-01-06
# 1   2013-01-13
# 2   2013-01-20
# 3   2013-01-27
# 4   2013-02-03
# ..         ...
# 464 2021-11-28
# 465 2021-12-05
# 466 2021-12-12
# 467 2021-12-19
# 468 2021-12-26
#
# [469 rows x 1 columns]

# %%
df1.columns = ['weaks'] 
df1
# Out:
#          weaks
# 0   2013-01-06
# 1   2013-01-13
# 2   2013-01-20
# 3   2013-01-27
# 4   2013-02-03
# ..         ...
# 464 2021-11-28
# 465 2021-12-05
# 466 2021-12-12
# 467 2021-12-19
# 468 2021-12-26
#
# [469 rows x 1 columns]

# %%
df_n=df1.join(df)

# %%
df = df_n
df
# Out:
#          weaks    Цена
# 0   2013-01-06  416,95
# 1   2013-01-13  422,35
# 2   2013-01-20  413,05
# 3   2013-01-27  421,05
# 4   2013-02-03  400,90
# ..         ...     ...
# 464 2021-11-28  108,60
# 465 2021-12-05  111,90
# 466 2021-12-12  111,10
# 467 2021-12-19  108,30
# 468 2021-12-26  103,75
#
# [469 rows x 2 columns]

# %%
df = df.rename(columns={'Цена': 'stocks'})
df
# Out:
#          weaks  stocks
# 0   2013-01-06  416,95
# 1   2013-01-13  422,35
# 2   2013-01-20  413,05
# 3   2013-01-27  421,05
# 4   2013-02-03  400,90
# ..         ...     ...
# 464 2021-11-28  108,60
# 465 2021-12-05  111,90
# 466 2021-12-12  111,10
# 467 2021-12-19  108,30
# 468 2021-12-26  103,75
#
# [469 rows x 2 columns]

# %%
arr = []
for s in df.stocks:
  s = s.replace(',', '.')  # заменяем запятую на точку
  x = int(float(s))  # преобразуем строку в число, используя float(), а затем int()
  arr.append(x)
len(arr)
# Out:
# 469

# %%
df.stocks = arr

# %%
df
# Out:
#          weaks  stocks
# 0   2013-01-06     416
# 1   2013-01-13     422
# 2   2013-01-20     413
# 3   2013-01-27     421
# 4   2013-02-03     400
# ..         ...     ...
# 464 2021-11-28     108
# 465 2021-12-05     111
# 466 2021-12-12     111
# 467 2021-12-19     108
# 468 2021-12-26     103
#
# [469 rows x 2 columns]
